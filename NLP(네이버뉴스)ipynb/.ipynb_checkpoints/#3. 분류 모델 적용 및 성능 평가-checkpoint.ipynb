# %% [markdown]
# ### train, test 데이터셋 분리..
#
# 일단 뉴스 데이터 300개 정도 분류 해둠...

# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv(f'csv/{search} 뉴스원문{num}.csv')
samsung_df = pd.read_csv('csv/samsung_data_set.csv',encoding='cp949')
samsung_df.dropna(axis=0,inplace=True)
samsung_df.head(10)
# Out:
#                date                                 title  sentiment
# 0   2023-05-30 9:00       삼성전자, 갤럭시·노트북·TV서 '자가 수리' 국내 도입        1.0
# 1  2023-05-30 10:43                 삼성전자 갤럭시, 이제 내손으로 고친다        1.0
# 2  2023-05-30 11:09         [특징주] 삼성전자·SK하이닉스, 52주 신고가 기록        1.0
# 3  2023-05-30 14:01      "청년에 일경험"…SK하이닉스·삼성전자 등 2100명 모집        1.0
# 4  2023-05-30 11:21       작년 주주 배당액 1위는 삼성전자…총 배당금은 6.7%↓        0.0
# 5   2023-05-30 9:29    갤S22·갤북 스스로 고친다…삼성전자 ‘자가 수리’ 국내 도입        1.0
# 6   2023-05-30 9:26  "이번엔 중동"…삼성전자, 두바이 리조트서 2023년형 TV 공개        1.0
# 7  2023-05-30 11:06       삼성전자, 두바이서 2023년형 네오QLED 신제품 선봬        1.0
# 8  2023-05-30 11:06   "이제 집에서 고치세요"...삼성전자, '자가 수리' 국내 도입        1.0
# 9  2023-05-30 18:00     "머스크 불만 터트릴 지경인데"…삼성전자·하이닉스 웃는 이유        1.0

# %%
kakao_df = pd.read_csv('csv/kakao_data_set.csv',encoding='cp949')
kakao_df.head(10)
# Out:
#                date                                  title  sentiment
# 0   2023-05-30 9:52        카카오, 세 번째 ESG보고서…'서비스 장애' 대응 소개        0.0
# 1  2023-05-30 11:10          카카오페이증권, 미국 주식 환율우대 신청 서비스 오픈        1.0
# 2   2023-05-30 9:24      카카오, 2022 ESG 보고서 발간…지배구조 선진화 나선다        1.0
# 3  2023-05-30 11:01       카카오페이 “대출갈아타기 사전신청자 70% 1금융권 고객”        1.0
# 4  2023-05-30 10:42                 패션바이카카오, ‘헬로 썸머 위크’ 진행        1.0
# 5  2023-05-30 11:25               카카오TV의 씁쓸한 퇴장…위기의 국내 OTT        0.0
# 6  2023-05-30 16:16  네이버 수준으로 설비투자 늘리는 카카오… ‘먹통 카톡’ 오명 벗을까        1.0
# 7   2023-05-30 3:02          카카오, 문어발식 확장 멈춘다더니… 계열사 더 늘었다        0.0
# 8   2023-05-30 8:22             SPC·카카오·매일유업…사옥을 짓지 않는 이유는        NaN
# 9   2023-05-30 9:58            관광公·카카오·티맵 등 외래객 교통편의 공조 활발        1.0

# %%
kakao_df.dropna(axis=0,inplace=True)
kakao_df.tail(10)
# Out:
#                  date                                title  sentiment
# 112  2023-05-30 15:02            기아 "유럽향 EV9으로 전동화 전환에 박차"        1.0
# 113  2023-05-30 13:53          日정부 "北미사일 일본 영역 낙하 우려되면 요격"        0.0
# 129  2023-05-30 18:11     토스뱅크 1분기 순손실 280억원…연체율 인뱅 최고로 올라        0.0
# 160  2023-05-30 17:39        주가 하락에 베팅 늘었나 대차잔고 82조원 '역대급'        1.0
# 181  2023-05-30 11:25                KAIST, 창업생태계 활성화 '박차'        1.0
# 182  2023-05-30 10:41        금감원, 주가조작·불공정거래와의 전쟁…특별단속반 투입        0.0
# 187  2023-05-30 15:33  국민연금 올 1분기 수익률 6.35%…작년 손실 상당 부분 만회        1.0
# 197  2023-05-30 14:21     알라딘 전자책 100만권 해킹…"출판산업 근간 흔들 사건"        0.0
# 201  2023-05-30 12:18   10명 중 4명 '스마트폰 과의존'…청소년 정신건강 '빨간불'        0.0
# 208   2023-05-30 9:55        누리호 성공 기여' KAI, 우주산업화 주도 '속도'        1.0

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 208
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       40 non-null     object
#  1   title      40 non-null     object
#  2   sentiment  40 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB
